# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushsoni9784/Computer_Vision-Adhoc/blob/master/Computer_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
#images reading
img=cv2.imread("dog.jpg")

# %%
img
# Out:
# array([[[163, 149, 137],
#         [164, 150, 138],
#         [165, 151, 139],
#         ...,
#         [133, 123, 113],
#         [135, 125, 115],
#         [137, 127, 117]],
#
#        [[164, 150, 138],
#         [164, 150, 138],
#         [164, 150, 138],
#         ...,
#         [129, 119, 109],
#         [134, 122, 112],
#         [134, 124, 114]],
#
#        [[163, 149, 137],
#         [163, 149, 137],
#         [161, 147, 135],
#         ...,
#         [131, 119, 107],
#         [136, 122, 110],
#         [136, 124, 112]],
#
#        ...,
#
#        [[204, 188, 172],
#         [205, 189, 173],
#         [205, 189, 173],
#         ...,
#         [190, 174, 161],
#         [190, 174, 161],
#         [189, 173, 160]],
#
#        [[201, 185, 169],
#         [201, 185, 169],
#         [202, 186, 170],
#         ...,
#         [182, 166, 153],
#         [181, 165, 152],
#         [180, 164, 151]],
#
#        [[198, 182, 166],
#         [199, 183, 167],
#         [200, 184, 168],
# ...

# %%
# shape of image opencv support BGR  
img.shape
# Out:
# (375, 500, 3)

# %%
#printing type
type(img)
# Out:
# numpy.ndarray

# %%
#to display img
plt.imshow(img)
#wait to window to close 
cv2.waitKey(0)  # for infinite time
# Out:
# -1

# %%
from google.colab.patches import cv2_imshow

# %%
img1=cv2.imread("dog.jpg",1) # for balck n white
img2=cv2.imread("dog.jpg",0) # for coloured

# %%
#cv2.imshow("dog",img1)
#cv2.imshow("dog",img2)
